# %% [markdown]
# # 📚 LIA - Generador de Imágenes Estilo Cinemático Ultra-Realista
#
# Este notebook genera imágenes IA con calidad similar a las referencias mostradas (retratos, armas, personajes), usando modelos personalizados y prompts detallados.
#
# ---
#
# ## 🔧 1. Preparación del entorno
#
# Instalamos las bibliotecas necesarias.

# %%
# ✅ Instala dependencias necesarias
# !pip install diffusers transformers accelerate safetensors peft compel python-dotenv
# !pip install git+https://github.com/MTG/freesound-python.git

# %% [markdown]
# ## 📁 2. Clonar el repositorio de LIA (si no lo tienes ya)

# %%
# %cd /content
# !git clone https://github.com/sagadeangelo/LIA-lectura-inmersiva-aumentada.git || echo 'Ya existe'
# %cd LIA-lectura-inmersiva-aumentada

# %% [markdown]
# ## 🔑 3. Configurar claves (opcional para Freesound y HuggingFace)

# %%
import os
from dotenv import load_dotenv

# Configura tus tokens manualmente aquí si no usas un archivo .env
os.environ['HUGGINGFACE_TOKEN'] = 'hf_xxx'
os.environ['FREESOUND_API_KEY'] = 'tu_token_de_freesound'

load_dotenv()

# %% [markdown]
# ## 🧠 4. Ejecutar el script principal de generación

# %%
# Ejecuta el script principal pasando el nombre del libro y su ruta
# !python scripts/generar_todo_desde_libro.py --libro angelo_ditox --ruta libros/angelo_ditox
